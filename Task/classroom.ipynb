# %% [markdown]
# ## nested list

# %%
list=[1,2,3,4,5,6]
list2=[[1,2,],[4,5,],[6,7,],[8,9,],[1,5,],]
list2[2][0]
# Out:
# 6

# %% [markdown]
# ## tuples datatype

# %%
tuple=("gokul","apple",12,2.0)
print(tuple)
# Out:
# ('gokul', 'apple', 12, 2.0)

# %%
tuple.index(2.0)
# Out:
# 3

# %% [markdown]
# ## dictionary datatype

# %%
dict={"name":"gokul"}
print(dict)
type(dict)
# Out:
# {'name': 'gokul'}
# dict

# %% [markdown]
# ## method in dictionary

# %%
key=["a","b","c"]
dict2=dict.fromkeys(key,20)

# %%
dict2
# Out:
# {'a': 20, 'b': 20, 'c': 20}

# %%
dict2.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
dict={"car":"thar","model":2026}
dict.pop("model")
print(dict)
# Out:
# {'car': 'thar'}

# %%
dict={"car":"thar","model":2026}
dict.popitem()
print(dict)
# Out:
# {'car': 'thar'}

# %%
dict.update({"price":10000000})
dict
# Out:
# {'car': 'thar', 'name': 'gokul', 'price': 10000000}
