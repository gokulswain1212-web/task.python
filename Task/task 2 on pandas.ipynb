# %% [markdown]
# # Easy Level (1–10)
# # Q1 Load the dataset and display the first 10 records.

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\LENOVO\\Downloads\\Bank_customer_churn.csv")
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# ...

# %% [markdown]
# # Q2 Display the last 15 customers.

# %%
ver=df.tail(15)
ver
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 9985       9986    15586914       Nepean          659    France    Male   36
# 9986       9987    15581736     Bartlett          673   Germany    Male   47
# 9987       9988    15588839      Mancini          606     Spain    Male   30
# 9988       9989    15589329      Pirozzi          775    France    Male   30
# 9989       9990    15605622     McMillan          841     Spain    Male   28
# 9990       9991    15798964   Nkemakonam          714   Germany    Male   33
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
# 9992       9993    15657105  Chukwualuka          726     Spain    Male   36
# 9993       9994    15569266       Rahman          644    France    Male   28
# 9994       9995    15719294         Wood          800    France  Female   29
# 9995       9996    15606229     Obijiaku          771    France    Male   39
# ...

# %% [markdown]
# # Q3 Show 7 random customer records.

# %%
ver=df.sample(7)
ver
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 6189       6190    15572408    Chambers          714   Germany    Male   39
# 1842       1843    15747222     Bentley          745     Spain  Female   35
# 6615       6616    15792934  Carruthers          661    France    Male   26
# 8204       8205    15570141       P'eng          724    France  Female   34
# 541         542    15626578       Milne          622    France    Male   26
# 2522       2523    15758056   Calabresi          558    France    Male   35
# 1933       1934    15815560       Bogle          666   Germany    Male   74
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 6189       3  149887.49              2          1               0
# 1842       8       0.00              2          1               1
# 6615       8       0.00              2          0               0
# 8204       3  132352.69              1          1               0
# ...

# %%
# Q4
Print complete dataset information and identify:
• Total columns
• Data type of each column
• Missing values
# Out:
#   Cell In[104], line 3
#     • Total columns
#     ^
# SyntaxError: invalid character '•' (U+2022)

# %%
ver=df.info()
print(ver)
print("data type",df.dtypes)
print("missing values:",df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB
# None
# data type RowNumber            int64
# CustomerId           int64
# ...

# %% [markdown]
# # Q5 Find missing values in every column.

# %%
ver=df.isnull().sum()
ver
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# # Q6 Display only numerical columns.

# %%
ver=df.select_dtypes(include=["number"]).columns
ver
# Out:
# Index(['RowNumber', 'CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %% [markdown]
# # Q7 Generate the statistical summary of numerical columns.

# %%
ver=df.describe()
ver
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# ## Q8 Find duplicate rows and print how many exist.

# %%
ver=df.duplicated().sum()
ver
# Out:
# np.int64(0)

# %% [markdown]
# ## Q9 Remove duplicate rows and store the cleaned dataset.

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ## Q10 Count how many customers have exited and how many have not exited.

# %%
ver=df['Exited'].value_counts()
ver
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
# Medium Level (11–20)
Q11
Rename the following columns:
CustomerId → Customer_ID
CreditScore → Credit_Score
EstimatedSalary → Salary
Exited → Churn
# Out:
#   Cell In[112], line 4
#     CustomerId → Customer_ID
#                ^
# SyntaxError: invalid character '→' (U+2192)

# %%
var=df.rename(columns ={"CustomerId":"Customer_ID","CreditScore":"Credit_Score","EstimatedSalary":"Salary","Exited":"Churn"},inplace=True)
df.columns
# Out:
# Index(['RowNumber', 'Customer_ID', 'Surname', 'Credit_Score', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'Salary', 'Churn'],
#       dtype='object')

# %%
## Q12
Add the prefix
Bank_
to every column name.
# Out:
#   Cell In[114], line 2
#     Add the prefix
#         ^
# SyntaxError: invalid syntax

# %%
ver=df.add_prefix('Bank_')
ver
# Out:
#       Bank_RowNumber  Bank_Customer_ID Bank_Surname  Bank_Credit_Score  \
# 0                  1          15634602     Hargrave                619
# 1                  2          15647311         Hill                608
# 2                  3          15619304         Onio                502
# 3                  4          15701354         Boni                699
# 4                  5          15737888     Mitchell                850
# ...              ...               ...          ...                ...
# 9995            9996          15606229     Obijiaku                771
# 9996            9997          15569892    Johnstone                516
# 9997            9998          15584532          Liu                709
# 9998            9999          15682355    Sabbatini                772
# 9999           10000          15628319       Walker                792
#
#      Bank_Geography Bank_Gender  Bank_Age  Bank_Tenure  Bank_Balance  \
# ...

# %% [markdown]
# ## Q13 Convert the Age column into float datatype.

# %%
ver['Bank_Age']=ver['Bank_Age'].astype("float")
ver['Bank_Age']
# Out:
# 0       42.0
# 1       41.0
# 2       42.0
# 3       39.0
# 4       43.0
#         ...
# 9995    39.0
# 9996    35.0
# 9997    36.0
# 9998    42.0
# 9999    28.0
# Name: Bank_Age, Length: 10000, dtype: float64

# %%
ver=df.add_prefix('Bank_')
ver
# Out:
#       Bank_RowNumber  Bank_Customer_ID Bank_Surname  Bank_Credit_Score  \
# 0                  1          15634602     Hargrave                619
# 1                  2          15647311         Hill                608
# 2                  3          15619304         Onio                502
# 3                  4          15701354         Boni                699
# 4                  5          15737888     Mitchell                850
# ...              ...               ...          ...                ...
# 9995            9996          15606229     Obijiaku                771
# 9996            9997          15569892    Johnstone                516
# 9997            9998          15584532          Liu                709
# 9998            9999          15682355    Sabbatini                772
# 9999           10000          15628319       Walker                792
#
#      Bank_Geography Bank_Gender  Bank_Age  Bank_Tenure  Bank_Balance  \
# ...

# %% [markdown]
# ## Q13 Convert the Age column into float datatype.

# %%
ver['Bank_Age']=ver['Bank_Age'].astype("float")
ver['Bank_Age']
# Out:
# 0       42.0
# 1       41.0
# 2       42.0
# 3       39.0
# 4       43.0
#         ...
# 9995    39.0
# 9996    35.0
# 9997    36.0
# 9998    42.0
# 9999    28.0
# Name: Bank_Age, Length: 10000, dtype: float64

# %% [markdown]
# ## Q14 Convert the Exited column into string datatype.

# %%
ver['Bank_Churn']=ver['Bank_Churn'].astype(str)
ver['Bank_Churn']
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Bank_Churn, Length: 10000, dtype: object

# %%
## Q15
Suppose the Balance column has missing values.
Replace them using the mean of the Balance column.
# Out:
#   Cell In[120], line 2
#     Suppose the Balance column has missing values.
#             ^
# SyntaxError: invalid syntax

# %%
mean=ver['Bank_Balance'].mean()
ver['Bank_Balance'].fillna(mean)
# Out:
# 0            0.00
# 1        83807.86
# 2       159660.80
# 3            0.00
# 4       125510.82
#           ...
# 9995         0.00
# 9996     57369.61
# 9997         0.00
# 9998     75075.31
# 9999    130142.79
# Name: Bank_Balance, Length: 10000, dtype: float64

# %%
## Q16
Suppose the Age column has missing values.
Replace them using the median age.
# Out:
#   Cell In[122], line 2
#     Suppose the Age column has missing values.
#             ^
# SyntaxError: invalid syntax

# %%
median=ver['Bank_Age'].median()
ver['Bank_Age']=ver['Bank_Age'].fillna(median)
print(ver['Bank_Age'])
# Out:
# 0       42.0
# 1       41.0
# 2       42.0
# 3       39.0
# 4       43.0
#         ...
# 9995    39.0
# 9996    35.0
# 9997    36.0
# 9998    42.0
# 9999    28.0
# Name: Bank_Age, Length: 10000, dtype: float64

# %%
print(ver['Bank_Age'].isnull().sum())
# Out:
# 0

# %%
## Q17
Display only the first five rows after renaming the columns.
# Out:
#   Cell In[125], line 2
#     Display only the first five rows after renaming the columns.
#             ^
# SyntaxError: invalid syntax

# %%
ver.head(5)
# Out:
#    Bank_RowNumber  Bank_Customer_ID Bank_Surname  Bank_Credit_Score  \
# 0               1          15634602     Hargrave                619
# 1               2          15647311         Hill                608
# 2               3          15619304         Onio                502
# 3               4          15701354         Boni                699
# 4               5          15737888     Mitchell                850
#
#   Bank_Geography Bank_Gender  Bank_Age  Bank_Tenure  Bank_Balance  \
# 0         France      Female      42.0            2          0.00
# 1          Spain      Female      41.0            1      83807.86
# 2         France      Female      42.0            8     159660.80
# 3         France      Female      39.0            1          0.00
# 4          Spain      Female      43.0            2     125510.82
#
#    Bank_NumOfProducts  Bank_HasCrCard  Bank_IsActiveMember  Bank_Salary  \
# 0                   1               1                    1    101348.88
# ...

# %%
## Q18
Create a new DataFrame by dropping these columns:
RowNumber
CustomerId
Surname
Display the first 10 rows.
# Out:
#   Cell In[127], line 2
#     Create a new DataFrame by dropping these columns:
#            ^
# SyntaxError: invalid syntax

# %%
ver.drop(columns=['Bank_RowNumber', 'Bank_Customer_ID', 'Bank_Surname'])
ver.head(10)
# Out:
#    Bank_RowNumber  Bank_Customer_ID Bank_Surname  Bank_Credit_Score  \
# 0               1          15634602     Hargrave                619
# 1               2          15647311         Hill                608
# 2               3          15619304         Onio                502
# 3               4          15701354         Boni                699
# 4               5          15737888     Mitchell                850
# 5               6          15574012          Chu                645
# 6               7          15592531     Bartlett                822
# 7               8          15656148       Obinna                376
# 8               9          15792365           He                501
# 9              10          15592389           H?                684
#
#   Bank_Geography Bank_Gender  Bank_Age  Bank_Tenure  Bank_Balance  \
# 0         France      Female      42.0            2          0.00
# 1          Spain      Female      41.0            1      83807.86
# ...

# %%
## Q20
Rename NumOfProducts to Products and HasCrCard to CreditCard.
# Out:
#   Cell In[129], line 2
#     Rename NumOfProducts to Products and HasCrCard to CreditCard.
#            ^
# SyntaxError: invalid syntax

# %%
ver.rename(columns ={"Bank_NumOfProducts":"Products","Bank_HasCrCard":"CreditCard"},inplace=True)
ver.columns
# Out:
# Index(['Bank_RowNumber', 'Bank_Customer_ID', 'Bank_Surname',
#        'Bank_Credit_Score', 'Bank_Geography', 'Bank_Gender', 'Bank_Age',
#        'Bank_Tenure', 'Bank_Balance', 'Products', 'CreditCard',
#        'Bank_IsActiveMember', 'Bank_Salary', 'Bank_Churn'],
#       dtype='object')

# %%
## Hard Level (21–30)
Q21 (Real Company Task)
Your manager wants cleaner column names.
Rename every column as follows:
RowNumber → Row_No
CustomerId → Customer_ID
Surname → Last_Name
CreditScore → Credit_Score
Geography → Country
Gender → Sex
EstimatedSalary → Salary
Exited → Target
Display the first five rows.
# Out:
#   Cell In[131], line 5
#     RowNumber → Row_No
#               ^
# SyntaxError: invalid character '→' (U+2192)

# %%
ver.rename(columns={
    "Bank_RowNumber" : "Row_No",
    "Bank_Customer_ID": "Customer_ID",
    "Bank_Surname" : "Last_Name",
    "Bank_Credit_Score" :"Credit_Score",
    "Bank_Geography" : "Country",
    "Bank_Gender" : "Sex",
    "Bank_Salary ":" Salary",
    "Bank_Churn": "Target",
},inplace=True)
ver.columns
# Out:
# Index(['Row_No', 'Customer_ID', 'Last_Name', 'Credit_Score', 'Country', 'Sex',
#        'Bank_Age', 'Bank_Tenure', 'Bank_Balance', 'Products', 'CreditCard',
#        'Bank_IsActiveMember', 'Bank_Salary', 'Target'],
#       dtype='object')

# %% [markdown]
# # Q22
# # Create a new DataFrame that contains only numeric columns.
# # Then generate its statistical summary.

# %%
numeric_ver = ver.select_dtypes(include='number')
numeric_ver.describe()
# Out:
#             Row_No   Customer_ID  Credit_Score      Bank_Age   Bank_Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#         Bank_Balance      Products   CreditCard  Bank_IsActiveMember  \
# count   10000.000000  10000.000000  10000.00000         10000.000000
# mean    76485.889288      1.530200      0.70550             0.515100
# std     62397.405202      0.581654      0.45584             0.499797
# ...

# %%
# Q23
Your company received duplicate customer records.
Tasks:
• Count duplicates.
• Remove duplicates.
• Display dataset information after cleaning.
# Out:
#   Cell In[134], line 4
#     • Count duplicates.
#     ^
# SyntaxError: invalid character '•' (U+2022)

# %%
ver.duplicated().sum()
ver.drop_duplicates()
# Out:
#       Row_No  Customer_ID  Last_Name  Credit_Score  Country     Sex  Bank_Age  \
# 0          1     15634602   Hargrave           619   France  Female      42.0
# 1          2     15647311       Hill           608    Spain  Female      41.0
# 2          3     15619304       Onio           502   France  Female      42.0
# 3          4     15701354       Boni           699   France  Female      39.0
# 4          5     15737888   Mitchell           850    Spain  Female      43.0
# ...      ...          ...        ...           ...      ...     ...       ...
# 9995    9996     15606229   Obijiaku           771   France    Male      39.0
# 9996    9997     15569892  Johnstone           516   France    Male      35.0
# 9997    9998     15584532        Liu           709   France  Female      36.0
# 9998    9999     15682355  Sabbatini           772  Germany    Male      42.0
# 9999   10000     15628319     Walker           792   France  Female      28.0
#
# ...

# %%
ver.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Q24
Management wants every column name to begin with
Customer_

Sumit Sir Notes
Apply this transformation using the appropriate method.
# Out:
#   Cell In[137], line 2
#     Management wants every column name to begin with
#                ^
# SyntaxError: invalid syntax

# %%
ver=ver.add_prefix("Customer_")
ver
ver.head(5)
# Out:
#    Customer_Row_No  Customer_Customer_ID Customer_Last_Name  \
# 0                1              15634602           Hargrave
# 1                2              15647311               Hill
# 2                3              15619304               Onio
# 3                4              15701354               Boni
# 4                5              15737888           Mitchell
#
#    Customer_Credit_Score Customer_Country Customer_Sex  Customer_Bank_Age  \
# 0                    619           France       Female               42.0
# 1                    608            Spain       Female               41.0
# 2                    502           France       Female               42.0
# 3                    699           France       Female               39.0
# 4                    850            Spain       Female               43.0
#
#    Customer_Bank_Tenure  Customer_Bank_Balance  Customer_Products  \
# 0                     2                   0.00                  1
# ...

# %%
ver.columns = ver.columns.str.replace('Customer_Customer_', 'Customer_', regex=False)

ver.head(5)
# Out:
#    Customer_Row_No  Customer_ID Customer_Last_Name  Customer_Credit_Score  \
# 0                1     15634602           Hargrave                    619
# 1                2     15647311               Hill                    608
# 2                3     15619304               Onio                    502
# 3                4     15701354               Boni                    699
# 4                5     15737888           Mitchell                    850
#
#   Customer_Country Customer_Sex  Customer_Bank_Age  Customer_Bank_Tenure  \
# 0           France       Female               42.0                     2
# 1            Spain       Female               41.0                     1
# 2           France       Female               42.0                     8
# 3           France       Female               39.0                     1
# 4            Spain       Female               43.0                     2
#
#    Customer_Bank_Balance  Customer_Products  Customer_CreditCard  \
# ...

# %%
## Q25
After renaming the columns, convert
Age
Balance
Salary
to float datatype.
Print dataset information.
# Out:
#   Cell In[140], line 2
#     After renaming the columns, convert
#           ^
# SyntaxError: invalid syntax

# %%
ver[['Customer_Bank_Age', 'Customer_Bank_Balance', 'Customer_Bank_Salary']] = ver[['Customer_Bank_Age', 'Customer_Bank_Balance', 'Customer_Bank_Salary']].astype(float)

ver[['Customer_Bank_Age', 'Customer_Bank_Balance', 'Customer_Bank_Salary']]
# Out:
#       Customer_Bank_Age  Customer_Bank_Balance  Customer_Bank_Salary
# 0                  42.0                   0.00             101348.88
# 1                  41.0               83807.86             112542.58
# 2                  42.0              159660.80             113931.57
# 3                  39.0                   0.00              93826.63
# 4                  43.0              125510.82              79084.10
# ...                 ...                    ...                   ...
# 9995               39.0                   0.00              96270.64
# 9996               35.0               57369.61             101699.77
# 9997               36.0                   0.00              42085.58
# 9998               42.0               75075.31              92888.52
# 9999               28.0              130142.79              38190.78
#
# [10000 rows x 3 columns]

# %%
## Q26
Assume CreditScore contains missing values.
Replace them with the median CreditScore.
# Out:
#   Cell In[142], line 2
#     Assume CreditScore contains missing values.
#            ^
# SyntaxError: invalid syntax

# %%
ver['Customer_Credit_Score'].isnull().sum()
# Out:
# np.int64(0)

# %%
median=ver['Customer_Credit_Score'].median()
median
# Out:
# 652.0

# %%
## Q27
Assume EstimatedSalary contains missing values.
Replace them with the mean salary.
Then print the first eight rows.

# %%
ver['Customer_Bank_Salary'].isnull().sum()
# Out:
# np.int64(0)

# %%
mean=ver['Customer_Bank_Salary'].mean()
mean
# Out:
# np.float64(100090.239881)

# %%
ver['Customer_Bank_Salary'].fillna(mean)
# Out:
# 0       101348.88
# 1       112542.58
# 2       113931.57
# 3        93826.63
# 4        79084.10
#           ...
# 9995     96270.64
# 9996    101699.77
# 9997     42085.58
# 9998     92888.52
# 9999     38190.78
# Name: Customer_Bank_Salary, Length: 10000, dtype: float64

# %%
ver.head(8)
# Out:
#    Customer_Row_No  Customer_ID Customer_Last_Name  Customer_Credit_Score  \
# 0                1     15634602           Hargrave                    619
# 1                2     15647311               Hill                    608
# 2                3     15619304               Onio                    502
# 3                4     15701354               Boni                    699
# 4                5     15737888           Mitchell                    850
# 5                6     15574012                Chu                    645
# 6                7     15592531           Bartlett                    822
# 7                8     15656148             Obinna                    376
#
#   Customer_Country Customer_Sex  Customer_Bank_Age  Customer_Bank_Tenure  \
# 0           France       Female               42.0                     2
# 1            Spain       Female               41.0                     1
# 2           France       Female               42.0                     8
# ...

# %%
## Q28 (Data Cleaning Challenge)
Perform all the following:
• Remove duplicate rows.
• Rename Exited to Target.
• Convert Target to string.
• Display dataset information.

# %%
ver['Customer_Target']=ver['Customer_Target'].astype("str")
ver['Customer_Target']
# Out:
# 0       1.0
# 1       0.0
# 2       1.0
# 3       0.0
# 4       0.0
#        ...
# 9995    0.0
# 9996    0.0
# 9997    1.0
# 9998    1.0
# 9999    0.0
# Name: Customer_Target, Length: 10000, dtype: object

# %%
ver.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Customer_Row_No               10000 non-null  int64
#  1   Customer_ID                   10000 non-null  int64
#  2   Customer_Last_Name            10000 non-null  object
#  3   Customer_Credit_Score         10000 non-null  int64
#  4   Customer_Country              10000 non-null  object
#  5   Customer_Sex                  10000 non-null  object
#  6   Customer_Bank_Age             10000 non-null  float64
#  7   Customer_Bank_Tenure          10000 non-null  int64
#  8   Customer_Bank_Balance         10000 non-null  float64
#  9   Customer_Products             10000 non-null  int64
#  10  Customer_CreditCard           10000 non-null  int64
#  11  Customer_Bank_IsActiveMember  10000 non-null  int64
# ...

# %%
## Q29 (Transformation Challenge)
Create a copy of the dataset.

Sumit Sir Notes
Perform these transformations:
• Rename Gender to CustomerGender
• Rename Geography to Country
• Add prefix Bank_
• Remove RowNumber
• Display first 10 rows

# %%
ver.head(2)
# Out:
#    Customer_Row_No  Customer_ID Customer_Last_Name  Customer_Credit_Score  \
# 0                1     15634602           Hargrave                    619
# 1                2     15647311               Hill                    608
#
#   Customer_Country Customer_Sex  Customer_Bank_Age  Customer_Bank_Tenure  \
# 0           France       Female               42.0                     2
# 1            Spain       Female               41.0                     1
#
#    Customer_Bank_Balance  Customer_Products  Customer_CreditCard  \
# 0                   0.00                  1                    1
# 1               83807.86                  1                    0
#
#    Customer_Bank_IsActiveMember  Customer_Bank_Salary Customer_Target
# 0                             1             101348.88             1.0
# 1                             1             112542.58             0.0

# %%
ver.to_csv('cleaned_data2.csv', index=False)
