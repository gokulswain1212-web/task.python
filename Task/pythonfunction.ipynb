# %% [markdown]
# ## 1-5: Functions with No Parameters

# %% [markdown]
# ## 1. Write a function greet() that prints "Hello, Welcome to Python!".

# %%
def greet():

    return "hello ,welcome to python!"

greet()
# Out:
# 'hello ,welcome to python!'

# %% [markdown]
# ## 2. Create a function show_date() that prints the current date and time.

# %%
def show_date(date,time):
    return  f"my date is{date} time is {time}"


show_date(17,3.17)
# Out:
# 'my date is17 time is 3.17'

# %% [markdown]
# ## 3. Write a function print_square() that prints the square of numbers from 1 to 10.

# %%
def print_square():

    for i in range(1,10):

       print(i*i)

print_square()
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %% [markdown]
# ## 4. Make a function motivation() that prints any motivational quote.

# %%
def motivation():
    return "never give up"


motivation()
# Out:
# 'never give up'

# %% [markdown]
# ## 5. Write a function line() that prints 50 dashes (-).

# %%
def function_line():
   
    
        print(50* '-')

function_line()
# Out:
# --------------------------------------------------

# %% [markdown]
# ## 6. Write a function greet_user(name="Guest") that greets the user.

# %%
def greet_user(name="Guest") :
    
    return f"my name in {name}  good afternoon"

greet_user()
# Out:
# 'my name in Guest  good afternoon'

# %% [markdown]
# ## 7. Create a function power(base, exp=2) that returns base raised to exp.

# %%
def function_power(base, exp=2):
    c=base**exp

    return c

function_power(5)
# Out:
# 25

# %% [markdown]
# ## 8. Write a function student_info(name, age=18, city="Delhi").

# %%
def student_info(name, age=18, city="Delhi"):
    return f"my name is {name} and my age is {age} i am from{city}"


student_info("gokul")
# Out:
# 'my name is gokul and my age is 18 i am fromDelhi'

# %% [markdown]
# ## 9. Make a function add_numbers(a, b=0, c=0) that returns sum of three numbers.

# %%
def add_numbers(a, b=0, c=0):
    c=a+b+c
    return c

add_numbers(4,5,6)
# Out:
# 15

# %% [markdown]
# ## 10. Write a function repeat_message(msg, times=3) that prints message times times.

# %%
def repeat_message(msg, times=3):
    for i in range(times):
       print(msg)

    
repeat_message("hello")
# Out:
# hello
# hello
# hello

# %% [markdown]
# ## 11. Create a function calculate_discount(price, discount=10).

# %%
def calculate_discount(price, discount=10):

# %% [markdown]
# ## 12. Write a function introduce(name="Unknown", profession="Student").

# %%
def introduce(name="Unknown", profession="Student"):
    return f"my name is :{name} my profession is :{ profession}"

introduce()
# Out:
# 'my name is :Unknown my profession is :Student'

# %% [markdown]
# ## 13. Write a function full_name(first, last) and call it using positional arguments.

# %%
def full_name(first, last):
     #return f"my name is {first} {last}"
    #return(first ,last)
    print(last,first)

    #return f"my name is {first} {last}"


full_name("gokul","swain")
# Out:
# swain gokul

# %% [markdown]
# ## 14. Call the same function using keyword arguments.

# %%
def full_name(first, last):
    
    print (first,last)
full_name("gokul","swain")
# Out:
# gokul swain

# %% [markdown]
# ## 15. Write a function details(name, age, city) and demonstrate both positional and keyword
# calls.

# %%
def details(name, age, city):
    return name,age,city


details("gokul",21,"berhampur")
# Out:
# ('gokul', 21, 'berhampur')

# %% [markdown]
# ## 16. Create a function calculate(a, b, operation) and show how keyword args improve
# readability.

# %% [markdown]
# def function_calculate(a, b, operation):
#     if operation=="+":
#         print(a+b)
#     elif operation=="-":
#         print(a-b)
#
#
# function_calculate(a=4, b=5, operation="+")

# %% [markdown]
# ## 17. Write a function order(item, quantity, price) and call it with mixed positional + keyword.

# %%
def function_order(item, quantity, price):
    return f"item: {item} quantity:{quantity}  price: {price}"

function_order(item="pen", quantity="2", price=10)
# Out:
# 'item: pen quantity:2  price: 10'

# %% [markdown]
# ## 18. What is the advantage of using keyword arguments over positional?

# %% [markdown]
# ## *19-25: args (Multiple Positional Arguments)

# %% [markdown]
#  ## 19. Write a function add_all(*args) that returns sum of all numbers passed.

# %%
def add_all(*number):
    c=sum(number)
    return c
add_all(1,2,3,4,5,6,7,8,9)
# Out:
# 45

# %% [markdown]
# ## 27. Create a function create_profile(**kwargs) that prints name, age, city, etc.

# %%
def create_profile(**parsion):

    print("my name is:",parsion["name"])
    print("age:",parsion["age"])
    print("city:",parsion["city"])



create_profile(name="gokul",age=21,city="barhampur")
# Out:
# my name is: gokul
# age: 21
# city: barhampur

# %% [markdown]
# ## 28. Write a function calculate_total(**kwargs) where keys are item names and values are
# prices.

# %%
def calculate_total(**calculate):
   # print("pen:",calculate["pen"])
   # print("chocolate:",calculate["chocolate"])
    #print("biscut:",calculate["biscut"])
    total=0
    for item,price in calculate.items():

        
        
        print(f"{item} : {price}")
        total+=price
        print("total:",total)

        


calculate_total(pen=10,chocolate=60,biscut=30)
# Out:
# pen : 10
# total: 10
# chocolate : 60
# total: 70
# biscut : 30
# total: 100

# %% [markdown]
# ## 29. Make a function display_info(name, **kwargs) that prints name and other details.

# %%
def display_info(name, **kwargs):

    print("name:",name)
    print("age:",kwargs["age"])
    print("city:",kwargs["city"])



display_info(name="gokul",age=21,city="barhampur")
# Out:
# name: gokul
# age: 21
# city: barhampur

# %% [markdown]
# ## 30. Write a function save_data(**kwargs) that prints "Saving data:" followed by all key-value
# pairs.

# %%
def save_data(**kwargs):
