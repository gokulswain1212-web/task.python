# %% [markdown]
# ## 1 creat a dictionary student with keys "name","age",city and print it

# %%
student={"name":"gokul", "age":21,"city":"barhampur"}

print(student)
# Out:
# {'name': 'gokul', 'age': 21, 'city': 'barhampur'}

# %% [markdown]
# ## 2 give d={"a":1,"b":2,"c":3} print all keys using keys()method

# %%
d={
    "a":1,"b":2,"c":3
}
d.keys()
print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# ## 3 given d={"a":1,"b":2}print all value using nalue() method

# %%
d={
    "a":1,
    "b":2,
}
d.values()
print(d)
# Out:
# {'a': 1, 'b': 2}

# %% [markdown]
# ## 4 using get()   to safely get the value of key "name" from dictionary d={"name":"sumit","age":25}

# %%
d={
    "name":"gokul",
    "age":25,
    
}
d.get("name")
# Out:
# 'gokul'

# %% [markdown]
# ## 5 creat a tuple with 5 number and print its type and length

# %%
tup=(1,2,3,4,5)
type(tup)
# Out:
# tuple

# %%
tup
# Out:
# (1, 2, 3, 4, 5)

# %%
len(tup)
# Out:
# 5

# %% [markdown]
# ## 6 creat a tuple=(10,20,30,40,50) and use count() to count how many time 20 apprars

# %%
tup=(10,20,30,40,50)
tup.count(20)
# Out:
# 1

# %%
tup
# Out:
# (10, 20, 30, 40, 50)

# %% [markdown]
# ## 7 use index() method on tuple(10,20,30,40,)to find the position of 30

# %%
tup=(10,20,30,40)
tup.index(30)
# Out:
# 2

# %%
tup
# Out:
# (10, 20, 30, 40)

# %% [markdown]
# ## 8 creat an empty dictionary add 3 keys value pairs using assignment

# %%
dict={}
dict.update({"name":"gokul","age":21,"study":"ds"})
print(dict)
# Out:
# {'name': 'gokul', 'age': 21, 'study': 'ds'}

# %%
dict
# Out:
# {'name': 'gokul', 'age': 21, 'study': 'ds'}

# %% [markdown]
# ## 9 given d={"a":1,"b":2}use update() to add {"c":3,"d":4}

# %%
d={
    "a":1,
    "b":2,
}
d.update({"c":3,"d":4})
print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
# ## 10 remove the key "age" from  dictionary student={"name":"gokul","age":22,"city":"berhampur"} using pop()

# %%
student={
    "name":"gokul",
    "age":22,
    "city":"berhampur",
}
student.pop("age")
print(student)
# Out:
# {'name': 'gokul', 'city': 'berhampur'}

# %% [markdown]
# ## 11 use popitem() on dictionary d={"x":10,"y":20,"z":30} and print the remove item

# %%
d={
    "x":10,
    "y":20,
    "z":30
}
s=d.popitem()
print(d)
print(s)
# Out:
# {'x': 10, 'y': 20}
# ('z', 30)

# %% [markdown]
# ## 12  creat a copy of dictionary d={"a":1,"b":2} using copy()method

# %%
d={"a":1,"b":2} 
d.copy()
print(d)
# Out:
# {'a': 1, 'b': 2}

# %% [markdown]
# ## 13  use fromkeys() to creat a dictionary with keys["red","green","blue"] and defult valur 0

# %%
keys=["red","green","blue"]

d=d.fromkeys(keys,0)
print(d)
# Out:
# {'red': 0, 'green': 0, 'blue': 0}

# %% [markdown]
# ## 14 creat a tuple with mixed data type and try to change one element(show error)

# %%
tup("gokul",22,2.0,)
tup.update(22)
tup
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 tup("gokul",22,2.0,)
#       2 tup.update(22)
#       3 tup
#
# TypeError: 'tuple' object is not callable

# %% [markdown]
# ## 15 given d={"name":"gokul"} use  setdefult{"age":25} and print the dictionary

# %%
d={
    "name":"gokul"
}
d.setdefault("age",25) 
print(d)
# Out:
# {'name': 'gokul', 'age': 25}

# %% [markdown]
# ## 16 creat a dictionary add 3 item using update() then rempve the list inserted item using popitem()

# %%
d={}
d.update({"name":"gokul","age":21,"car":"thar"})
a=d.popitem()

print(d)
print(a)
# Out:
# {'name': 'gokul', 'age': 21}
# ('car', 'thar')

# %% [markdown]
# ## 17 creat tuple of 6 number.find the index of a number and count how many time it appears

# %%
tup=(1,2,3,3,4,3)
tup.index(3)
tup.count(3)
print(tup)
# Out:
# (1, 2, 3, 3, 4, 3)

# %%
tup.count(3)
# Out:
# 3

# %% [markdown]
# ## 18 take 3 student name and mark as input and stor them in a dictionary

# %%
student={
    "name":"gokul","mark":80,
    "name":"binod","mark":90,
    "name":"akash","mark":70,
}
print(student)
# Out:
# {'name': 'akash', 'mark': 70}
