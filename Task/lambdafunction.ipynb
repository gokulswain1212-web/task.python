# %%
a=lambda x:x*x

a(5)
# Out:
# 25

# %% [markdown]
# ## 2.Write a lambda function to return the cube of a number.

# %%
a=lambda x:x*3

a(7)
# Out:
# 21

# %% [markdown]
# ## 3.Write a lambda function to add two numbers.

# %%
s=lambda x,y: x+y
   

s(2,5)
# Out:
# 7

# %% [markdown]
# ## 4.Write a lambda function to find the maximum of two numbers.

# %%
b= lambda x,y: "x" if x>y else "y"

b(56,84)
# Out:
# 'y'

# %% [markdown]
# ##  5 Write a lambda function that returns "Even" if a number is even; otherwise "Odd".

# %%
b=lambda x: "even"if x%2==0 else "add"




b(5)
# Out:
# 'add'

# %% [markdown]
# ## 6.Use map() with lambda to square every element of a list.

# %%
number=[1,5,3,4,7,8]

result=tuple(map(lambda x: x*2 ,number ))

result
# Out:
# (2, 10, 6, 8, 14, 16)

# %% [markdown]
# ## 7.Use filter() with lambda to keep only even numbers.

# %%
number=[1,2,3,4,5,6,7,8,9]

result=list(filter(lambda x: x%2==0 ,number ))


result
# Out:
# [2, 4, 6, 8]

# %% [markdown]
# ## 8.Use filter() with lambda to keep numbers greater than 50.

# %%
number=[45,12,89,5,65,84]


greater=tuple(filter(lambda x: x>50 , number))

greater
# Out:
# (89, 65, 84)

# %% [markdown]
# ## 9.Sort a list of numbers in ascending order using lambda.

# %%
a=[2,3,5,4,7,6]

result=(lambda x: sorted(x)) (a)

result
# Out:
# [2, 3, 4, 5, 6, 7]

# %% [markdown]
# ## 10.Sort a list of numbers in descending order using lambda.

# %%
a=[2,3,5,4,7,6]

result=(lambda x: x[::-1]) (a)

result
# Out:
# [6, 7, 4, 5, 3, 2]

# %% [markdown]
# ## 11 Use reduce() with lambda to find the sum of all numbers.
# [10,20,30,40]

# %%
#b=[10,20,30,40]
from functools import reduce
#result= reduce(lambda x,y: x+y,b)
#number=[10,20,30,40]

#result=lambda x,y:x+y ,number
#result
number= [10, 20, 30, 40]

result = reduce(lambda x, y: x + y, number)

print(result)
# Out:
# 100

# %% [markdown]
# ## 12.Use reduce() with lambda to find the product of all numbers.[2,3,4,5]

# %%
from functools import reduce

number=[2,3,4,5]

result=reduce(lambda x,y:x*y ,number)
result
# Out:
# 120

# %% [markdown]
# ## 13.Sort the following list according to age.
# students = [
# ("Ram",22),
# ("Amit",19),
# ("Neha",25),
# ("Raj",20)
# ]

# %%
students = [ ("Ram",22), ("Amit",19), ("Neha",25), ("Raj",20) ]

result=(lambda x: sorted(x)) (students)

result
# Out:
# [('Amit', 19), ('Neha', 25), ('Raj', 20), ('Ram', 22)]

# %% [markdown]
# ## 14.Sort the following dictionary by values.
# marks = {
#
# Sumit Sir Notes
# "A":80,
# "B":95,
# "C":70,
# "D":88
# }

# %%
marks = {"A":80, "B":95, "C":70, "D":88 }

result=sorted(marks.items(),key=lambda x:x[1])

result
# Out:
# [('C', 70), ('A', 80), ('D', 88), ('B', 95)]

# %% [markdown]
# ## 15.Find the longest string using lambda.
# ["apple","banana","kiwi","watermelon"]

# %% [markdown]
# ## 16.Use lambda with max() to find the student having the highest marks.
# students = [
# ("Ram",85),
# ("Amit",91),
# ("Neha",78)
# ]

# %%
students = [ ("Ram",85), ("Amit",91), ("Neha",78) ]

result=max(students,key=lambda x:x[1])

result
# Out:
# ('Amit', 91)

# %% [markdown]
# ## 17.Use lambda with min() to find the employee with the lowest salary.
# employees = [
# ("A",35000),
# ("B",42000),
# ("C",28000)
# ]

# %%
employees = [ ("A",35000), ("B",42000), ("C",28000) ]

result=min(employees,key=lambda x:x[1])

result
# Out:
# ('C', 28000)

# %% [markdown]
# ## 18.Use map() with lambda to convert all names into uppercase.
# ["ram","amit","neha"]

# %%
name=["ram","amit","neha"]

result=list(map(lambda x:x.upper(),name))

result
# Out:
# ['RAM', 'AMIT', 'NEHA']

# %% [markdown]
# ## 20.Sort tuples based on the second element.
# [(1,5),(3,2),(2,8),(4,1)]

# %%
Skip to Main
lambdafunction
Last Checkpoint: 5 hours ago
[Python 3 (ipykernel)]
1.Write a lambda function to return the square of a number.
a=lambda x:x*x

a(5)

25

2.Write a lambda function to return the cube of a number.
a=lambda x:x*3

a(7)

21

3.Write a lambda function to add two numbers.
s=lambda x,y: x+y
   

s(2,5)

7

4.Write a lambda function to find the maximum of two numbers.
b= lambda x,y: "x" if x>y else "y"

b(56,84)

'y'

5 Write a lambda function that returns "Even" if a number is even; otherwise "Odd".
b=lambda x: "even"if x%2==0 else "add"




b(5)



'add'

6.Use map() with lambda to square every element of a list.
number=[1,5,3,4,7,8]

result=tuple(map(lambda x: x*2 ,number ))

result


(2, 10, 6, 8, 14, 16)

7.Use filter() with lambda to keep only even numbers.
number=[1,2,3,4,5,6,7,8,9]

result=list(filter(lambda x: x%2==0 ,number ))


result

[2, 4, 6, 8]

8.Use filter() with lambda to keep numbers greater than 50.
number=[45,12,89,5,65,84]


greater=tuple(filter(lambda x: x>50 , number))

greater

(89, 65, 84)

9.Sort a list of numbers in ascending order using lambda.
a=[2,3,5,4,7,6]

result=(lambda x: sorted(x)) (a)

result

[2, 3, 4, 5, 6, 7]

10.Sort a list of numbers in descending order using lambda.
a=[2,3,5,4,7,6]

result=(lambda x: x[::-1]) (a)

result

[6, 7, 4, 5, 3, 2]

11 Use reduce() with lambda to find the sum of all numbers.

[10,20,30,40]
#b=[10,20,30,40]
from functools import reduce
#result= reduce(lambda x,y: x+y,b)
#number=[10,20,30,40]

#result=lambda x,y:x+y ,number
#result
number= [10, 20, 30, 40]

result = reduce(lambda x, y: x + y, number)

print(result)

100

12.Use reduce() with lambda to find the product of all numbers.[2,3,4,5]
from functools import reduce

number=[2,3,4,5]

result=reduce(lambda x,y:x*y ,number)
result

120

13.Sort the following list according to age.

students = [ ("Ram",22), ("Amit",19), ("Neha",25), ("Raj",20) ]
students = [ ("Ram",22), ("Amit",19), ("Neha",25), ("Raj",20) ]

result=(lambda x: sorted(x)) (students)

result

[('Amit', 19), ('Neha', 25), ('Raj', 20), ('Ram', 22)]

14.Sort the following dictionary by values.

marks = {

Sumit Sir Notes "A":80, "B":95, "C":70, "D":88 }
marks = {"A":80, "B":95, "C":70, "D":88 }

result=sorted(marks.items(),key=lambda x:x[1])

result

[('C', 70), ('A', 80), ('D', 88), ('B', 95)]

15.Find the longest string using lambda.

["apple","banana","kiwi","watermelon"]

16.Use lambda with max() to find the student having the highest marks.

students = [ ("Ram",85), ("Amit",91), ("Neha",78) ]
students = [ ("Ram",85), ("Amit",91), ("Neha",78) ]

result=max(students,key=lambda x:x[1])

result

('Amit', 91)

17.Use lambda with min() to find the employee with the lowest salary.

employees = [ ("A",35000), ("B",42000), ("C",28000) ]
employees = [ ("A",35000), ("B",42000), ("C",28000) ]

result=min(employees,key=lambda x:x[1])

result

('C', 28000)

18.Use map() with lambda to convert all names into uppercase.

["ram","amit","neha"]
name=["ram","amit","neha"]

result=list(map(lambda x:x.upper(),name))

result

['RAM', 'AMIT', 'NEHA']

20.Sort tuples based on the second element.
# Out:
#   Cell In[5], line 5
#     1.Write a lambda function to return the square of a number.
#      ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ## 19.Filter all words having length greater than 5.["apple","banana","kiwi","orange","grapes"]

# %%
fruit=["apple","banana","kiwi","orange","grapes"]

result=list(filter(lambda x:len(x)>5,fruit))


result
# Out:
# ['banana', 'orange', 'grapes']

# %% [markdown]
# ## 20.Sort tuples based on the second element.[(1,5),(3,2),(2,8),(4,1)]

# %%
list_num=[(1,5),(3,2),(2,8),(4,1)]

result=tuple(sorted(list_num,key=lambda x: x[1]))

result
# Out:
# ((4, 1), (3, 2), (1, 5), (2, 8))

# %% [markdown]
# ## 21.Sort the following list of dictionaries based on salary.
# employees = [
# {"name":"Ram","salary":50000},
# {"name":"Amit","salary":65000},
# {"name":"Neha","salary":45000}
# ]

# %%
employees = [ {"name":"Ram","salary":50000}, {"name":"Amit","salary":65000}, {"name":"Neha","salary":45000} ]



result=list(sorted(employees,key=lambda x:x["salary"]))


result
# Out:
# [{'name': 'Neha', 'salary': 45000},
#  {'name': 'Ram', 'salary': 50000},
#  {'name': 'Amit', 'salary': 65000}]

# %%
##
