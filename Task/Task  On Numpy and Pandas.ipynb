# %% [markdown]
# # 1. Load the CSV using Pandas and display the first 10 rows.

# %%
import pandas as pd

df=pd.read_csv("C:\\Users\\LENOVO\\Downloads\\customer_data.csv")
df.head(10)
# Out:
#   Customer ID                Age           income_usd       credit Score  \
# 0  CUST-01861   45.86741673405659   28198.41033378447  660.5629175986682
# 1  CUST-00354   47.76516427959453   61312.83129054326            838 pts
# 2  CUST-01334                 NaN   44199.67123886594  613.1327753975876
# 3  CUST-00906   62.72357804628894   56259.90961066413  720.2369862405794
# 4  CUST-01290                 NaN  31238.641956219115   549.183252322903
# 5  CUST-01274                 NaN             $44,696                NaN
# 6  CUST-00939  49.283473578603065   44108.07924936186  793.2135772820182
# 7  CUST-01732  37.630009830989785   80888.86263734727              850.0
# 8  CUST-00066  47.520166822399105   50011.55555812526  796.7940989517157
# 9  CUST-01324                 NaN   84410.30823662701  482.3950728788773
#
#    tenure_years  monthly_visits  satisfaction       City customer_segment  \
# 0      5.274076             5.0      3.382150       Pune        consumer
# ...

# %% [markdown]
# ## 2. Check the number of rows and columns in the dataset.

# %%
df.shape
# Out:
# (2000, 15)

# %% [markdown]
# # 3. Display all column names and identify which column names containleading/trailing spaces or inconsistent capitalization.

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age ', 'income_usd', 'credit Score', 'tenure_years',
#        'monthly_visits', 'satisfaction', 'City', 'customer_segment', 'gender',
#        'is_active', 'churn_flag', 'signup_date', 'lead_source', 'notes_text'],
#       dtype='object')

# %% [markdown]
# ## 4. Check the data type of every column using Pandas.

# %%
df.dtypes
# Out:
# Customer ID          object
# Age                  object
# income_usd           object
# credit Score         object
# tenure_years        float64
# monthly_visits      float64
# satisfaction        float64
# City                 object
# customer_segment     object
# gender               object
# is_active            object
# churn_flag           object
# signup_date          object
# lead_source          object
# notes_text           object
# dtype: object

# %% [markdown]
# # 5. Calculate the number and percentage of missing values in every column.

# %%
miss_value=df.isnull().sum()
miss_value
# Out:
# Customer ID          20
# Age                 331
# income_usd          440
# credit Score        360
# tenure_years        258
# monthly_visits      280
# satisfaction        399
# City                300
# customer_segment    380
# gender              240
# is_active           340
# churn_flag          160
# signup_date         240
# lead_source         420
# notes_text          656
# dtype: int64

# %%
miss_per=miss_value / len(df)*100
miss_per
# Out:
# Customer ID          1.00
# Age                 16.55
# income_usd          22.00
# credit Score        18.00
# tenure_years        12.90
# monthly_visits      14.00
# satisfaction        19.95
# City                15.00
# customer_segment    19.00
# gender              12.00
# is_active           17.00
# churn_flag           8.00
# signup_date         12.00
# lead_source         21.00
# notes_text          32.80
# dtype: float64

# %% [markdown]
# ## 6. Find the rows where Customer ID is missing.

# %%
missing_value=df['Customer ID'].isnull().sum()
missing_value
# Out:
# np.int64(20)

# %% [markdown]
# # 7. Remove leading/trailing whitespace from all column names and convert themto lowercase with underscores.

# %%
df.columns.str.strip()
# Out:
# Index(['Customer ID', 'Age', 'income_usd', 'credit Score', 'tenure_years',
#        'monthly_visits', 'satisfaction', 'City', 'customer_segment', 'gender',
#        'is_active', 'churn_flag', 'signup_date', 'lead_source', 'notes_text'],
#       dtype='object')

# %%
df.columns.str.lower()
# Out:
# Index(['customer id', 'age ', 'income_usd', 'credit score', 'tenure_years',
#        'monthly_visits', 'satisfaction', 'city', 'customer_segment', 'gender',
#        'is_active', 'churn_flag', 'signup_date', 'lead_source', 'notes_text'],
#       dtype='object')

# %%
df.columns.str.replace(" ","_")
# Out:
# Index(['Age_', 'income_usd', 'credit_Score', 'tenure_years', 'monthly_visits',
#        'satisfaction', 'City', 'customer_segment', 'gender', 'is_active',
#        'churn_flag', 'signup_date', 'lead_source', 'notes_text'],
#       dtype='object')

# %% [markdown]
# # 8. Identify duplicate Customer ID values and count how many duplicates exist.

# %%
df['Customer ID']=df['Customer ID'].duplicated().sum()
df['Customer ID']
# Out:
# 0       19
# 1       19
# 2       19
# 3       19
# 4       19
#         ..
# 1995    19
# 1996    19
# 1997    19
# 1998    19
# 1999    19
# Name: Customer ID, Length: 2000, dtype: int64

# %%
df['Customer ID'].value_counts()
# Out:
# Customer ID
# 19    2000
# Name: count, dtype: int64

# %% [markdown]
# # 9. Remove duplicate customer records while keeping the first occurrence.

# %%
df.drop_duplicates(keep = 'first',inplace = True)

# %% [markdown]
# # 10.Find all unique values in the customer_segment column and identifyinconsistent categories such as Consumer, consumer, consumer , etc.

# %%
df['customer_segment'].value_counts()
# Out:
# customer_segment
# Consumer      666
# SMB           395
# Enterprise    293
# consumer      121
# UNKNOWN        76
# SMB.           69
# Name: count, dtype: int64

# %% [markdown]
# ## 11.Clean the customer_segment column by standardizing capitalization andwhitespace.

# %%
df['customer_segment'].str.title()
# Out:
# 0        Consumer
# 1         Consumer
# 2         Consumer
# 3       Enterprise
# 4       Enterprise
#            ...
# 1995      Consumer
# 1996           Smb
# 1997          Smb.
# 1998           Smb
# 1999      Consumer
# Name: customer_segment, Length: 2000, dtype: object

# %%
df['customer_segment'].str.replace("."," ")
# Out:
# 0        consumer
# 1         Consumer
# 2         Consumer
# 3       Enterprise
# 4       Enterprise
#            ...
# 1995      Consumer
# 1996           SMB
# 1997          SMB
# 1998           SMB
# 1999      Consumer
# Name: customer_segment, Length: 2000, dtype: object

# %% [markdown]
# ## 12.Find all unique values in the gender column and convert them into consistentcategories such as Male and Female.

# %%
# Find all unique values
df['gender'].unique()
# Out:
# array([nan, 'Male', 'm', 'Female', 'M', 'F', 'f'], dtype=object)

# %%
df['gender'] = df['gender'].str.strip().str.lower().replace({
    'm': 'Male',
    'male': 'Male',
    'f': 'Female',
    'female': 'Female'
})

df['gender']
# Out:
# 0          NaN
# 1         Male
# 2         Male
# 3         Male
# 4         Male
#          ...
# 1995      Male
# 1996      Male
# 1997    Female
# 1998       NaN
# 1999       NaN
# Name: gender, Length: 2000, dtype: object

# %%
df['gender'].unique()
# Out:
# array([nan, 'Male', 'Female'], dtype=object)

# %% [markdown]
# ## 13.Clean the is_active column so values such as Yes, yes, Y, 1 become 1, andNo, no, N, 0 become 0.
