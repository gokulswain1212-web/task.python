# %%
##1. Class Name: Shape
Problem
Create an abstract class named Shape.
Explanation
A shape can have different formulas for area and perimeter. Therefore, create two abstract
methods:
• area()
• perimeter()
Create subclasses like Circle and Rectangle and implement both methods.

# %%
from abc import ABC, abstractmethod
import math

class Shape(ABC):

    @abstractmethod
    def area(self):
        pass

    @abstractmethod
    def perimeter(self):
        pass



class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.radius


class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

    def perimeter(self):
        return 2 * (self.length + self.width)



circle = Circle(5)
rectangle = Rectangle(4, 6)

print("Circle Area =", circle.area())
print("Circle Perimeter =", circle.perimeter())

print("Rectangle Area =", rectangle.area())
print("Rectangle Perimeter =", rectangle.perimeter())
# Out:
# Circle Area = 78.53981633974483
# Circle Perimeter = 31.41592653589793
# Rectangle Area = 24
# Rectangle Perimeter = 20

# %%
## 2. Class Name: Vehicle
Problem
Create an abstract class named Vehicle.
Explanation
Every vehicle can start and stop, but each vehicle does it differently.
Create two abstract methods:
• start()
• stop()
create a Car class that implements both methods.

# %%
class Vehicle(ABC):


    @abstractmethod
    def start(self):
        pass


    @abstractmethod
    def stop(self):
        pass

class car(Vehicle):
    def start(self):
        print("car start when driver put key and push start buttom ")


    def stop(self):
        print("car stop when driver push break")



#car=Vehicle()
car=car()
car.start()
car.stop()
# Out:
# car start when driver put key and push start buttom
# car stop when driver push break

# %%
## 3. Class Name: Animal
Problem
Create an abstract class named Animal.
Explanation
Every animal makes a sound, but the sound depends on the animal
Create an abstract method:
• make_sound()
Create subclasses:
• Dog
• Cat
Each should implement its own sound.

# %%
class Animal(ABC):

    @abstractmethod
    def make_sound(self):
        pass   


class Dog(Animal):

    def make_sound(self):
        print("bhouuuuuuu !bhouuuuuu")


class Cat(Animal):

    def make_sound(self):
        print("meow !meow")


animal=Dog()
animal.make_sound()
animal=Cat()
animal.make_sound()
# Out:
# bhouuuuuuu !bhouuuuuu
# meow !meow

# %%
## 4. Class Name: Payment
Problem
Create an abstract class named Payment.
Explanation
Every payment processes money differently.
Create an abstract method:
• process_payment(amount)
Create subclasses:
• CreditCard
• Cash
Each should process the payment in its own way.

# %%
class Payment(ABC):


    @abstractmethod
    def process_payment(self,amount):
        pass


class CreditCard(Payment):


    def process_payment(self,amount):
        print("proccessing your CreditCard card amount",amount)

class Cash(Payment):

    def process_payment(self,amount):
        print("proccessing your cash amount",amount)



payment=CreditCard()
payment.process_payment(100)
payment=Cash()
payment.process_payment(500)
# Out:
# proccessing your CreditCard card amount 100
# proccessing your cash amount 500

# %%
## 5. Class Name: Report
Problem
Create an abstract class named Report.
Explanation
Different report formats generate reports differently.
Create an abstract method:
• generate()
Create:
• PDFReport
• ExcelReport
Each should generate the report differently.

# %%
class Report(ABC):

    @abstractmethod
    def  generate(self):
        pass
class PDFReport(Report):
    def  generate(self):
        print("generating your PDFReport")

class ExcelReport(Report):
    def generate(self):
        print("generating your ExcelReport ")


report=PDFReport()
report.generate()

report=ExcelReport()
report.generate()
# Out:
# generating your PDFReport
# generating your ExcelReport

# %%
## 6. Class Name: BankAccount
Problem
Create an abstract class named BankAccount.
Explanation
Different bank accounts calculate interest differently.
Create an abstract method:
• calculate_interest()
Create:
• SavingsAccount
Implement the interest calculation.

# %%
class BankAccount(ABC):

    @abstractmethod
    def calculate_interes(self):
        pass

class SavingsAccount(BankAccount):

    def __init__(self,balance,rate):
        self.Balance=balance
        self.Rate=rate

    def calculate_interes(self):
        interest=(self.Balance * self.Rate)/100
        print("your interest is ",interest)

    def display_info(self):
        print("your balance is",self.Balance)
        print("your rate is ",self.Rate)


bank=SavingsAccount(10000,4)
bank.calculate_interes()
bank.display_info()
# Out:
# your interest is  400.0
# your balance is 10000
# your rate is  4

# %%
## 7. Class Name: Device
Problem
Create an abstract class named Device.
Explanation
Every electronic device can be turned on and off.
Create abstract methods:
• turn_on()
• turn_off()
Implement them in a subclass such as Laptop or TV.

# %%
class Device(ABC):

    @abstractmethod
    def turn_on(self):
        pass

    @abstractmethod
    def turn_off(self):
        pass


class Laptop(Device):

    def turn_on(self):
        print("when you press on button then your laptop turn on")

    def turn_off(self):
        print("when you press off button then your laptop turn off")


class TV(Device):

    def turn_on(self):
        print("when you press on button then your tv turn on")

    def turn_off(self):
        print("when you press off button then your tv turn off")


device=Laptop()
device.turn_on()
device.turn_off()
device=TV()
device.turn_on()
device.turn_off()
# Out:
# when you press on button then your laptop turn on
# when you press off button then your laptop turn off
# when you press on button then your tv turn on
# when you press off button then your tv turn off

# %%
## 8. Class Name: Employee
Problem
Create an abstract class named Employee.
Explanation
Employees receive bonuses based on their roles.
Create an abstract method:-
• calculate_bonus()
Create subclass:
• Manager
Implement the bonus calculation.

# %%
class Employee(ABC):

    @abstractmethod
    def calculate_bonus(self):
        pass



class Manager(Employee):

    def __init__(self, salary):
        self.salary = salary

    def calculate_bonus(self):
        bonus = self.salary * 20 
        print("Manager Bonus =", bonus)



manager = Manager(50000)
manager.calculate_bonus()
# Out:
# Manager Bonus = 1000000

# %%
## 9. Class Name: Transport
Problem
Create an abstract class named Transport.
Explanation
Every transport moves differently and uses different fuel.
Create abstract methods:
• move()
• fuel_type()
Create subclasses like:
• Car
• Train

# %%
from abc import ABC, abstractmethod
class Transport(ABC):

    @abstractmethod
    def move(self):
        pass

    @abstractmethod
    def fuel_type(self):
        pass


class Car(Transport):

    def move(self):
        print("car move on road")

    def fuel_type(self):
        print("car use petrol as fuel")


class Train(Transport):

    def move(self):
        print("train move on train line")

    def fuel_type(self):
        print("train use electricity and diesel as fule")


tr=Car()
tr.move()
tr.fuel_type()
tr=Train()
tr.move()
tr.fuel_type()
# Out:
# car move on road
# car use petrol as fuel
# train move on train line
# train use electricity and diesel as fule

# %%
## 10. Class Name: Notification
Problem
Create an abstract class named Notification.
Explanation
Notifications can be sent in different ways.
Create abstract method:
• send(message)
Create subclasses:
• EmailNotification
• SMSNotification

# %%
class Notification(ABC):

    @abstractmethod
    def send(self,message):
        pass



class EmailNotification(Notification):

    def send(self,message):
        print("sending EmailNotification: ",message)

class SMSNotification(SMSNotification):

    def send(self,message):
        print("dending SMSNotification:",message)


msg=EmailNotification()
msg.send("your account has been created successfully")
mas=SMSNotification()
msg.send("your OTP is 524625")
# Out:
# sending EmailNotification:  your account has been created successfully
# sending EmailNotification:  your OTP is 524625

# %%
## 11. Class Name: FileHandler
Problem
Create an abstract class named FileHandler.
Explanation
Files can be read and written differently.
Create abstract methods:
• read()
• write(data)
Create subclasses like:
• TextFileHandler
• CSVFileHandler

# %%
class FileHandler(ABC):

    @abstractmethod
    def read(self):
        pass
    @abstractmethod
    def write(self,data):
        pass

class TextFileHandler(FileHandler):

    def read(self):
        print("Reading data from Text file")

    def write(self,data):
        print("write to text file",data)

class CSVFileHandler(FileHandler):

    def read(self):
        print("read data from csv file")

    def write(self,data):
        print("write to csv file",data)


file=TextFileHandler()
file.read()
file.write("Hello, this is a text file")
file=CSVFileHandler()
file.read()
file.write({"name":"gokul","age":21})
# Out:
# Reading data from Text file
# write to text file Hello, this is a text file
# read data from csv file
# write to csv file {'name': 'gokul', 'age': 21}

# %%
## 12. Class Name: GameCharacter
Problem
Create an abstract class named GameCharacter.
Explanation
Every game character attacks differently.
Create abstract method:
• attack()
Create subclasses:
• Warrior
• Mage

# %%
class GameCharacter(ABC):

    @abstractmethod
    def attack(self):
        pass

class warrior(GameCharacter):
    def attack(self):
        print("Warrior attacks with a sword ")

class Mage(GameCharacter):
    def attack(self):
        print("mage attacks with magic spell")


game=warrior()
game.attack()
game=Mage()
game.attack()
# Out:
# Warrior attacks with a sword
# mage attacks with magic spell

# %%
## 13. Class Name: Calculator
Problem
Create an abstract class named Calculator.
Explanation
Different calculators perform different operations.
Create abstract method:
• compute(a, b)
Create subclasses:
• AdditionCalculator
• MultiplicationCalculator

# %%
class Calculator(ABC):
    @abstractmethod
    def compute(self,a,b):
        pass
class AdditionCalculator(Calculator):
     def compute(serlf,a,b):
         c=a+b 
         #return c
         print("your AdditionCalculator is:",c)

class MultiplicationCalculator(Calculator):
    def compute(self,a,b):
        c=a*b
        #return c
        print("your MultiplicationCalculator is:",c)


calcu=AdditionCalculator()
calcu.compute(3,4)
calcu=MultiplicationCalculator()
calcu.compute(3,5)
# Out:
# your AdditionCalculator is: 7
# your MultiplicationCalculator is: 15

# %%
## 14. Class Name: Database
Problem
Create an abstract class named Database.
Explanation
Different databases connect and execute queries differently.
Create abstract methods:
• connect()
• query(sql)
Create subclasses:
• MySQLDatabase
• MongoDatabase

# %%
class Database(ABC):

    @abstractmethod
    def connect(self):
        pass

    @abstractmethod
    def query(self, sql):
        pass
class MySQLDatabase(Database):

    def connect(self):
        print("Connecting to MySQL Database")

    def query(self, sql):
        print(f"Executing MySQL query: {sql}")

class MongoDatabase(Database):

    def connect(self):
        print("Connecting to MongoDB Database")

    def query(self, sql):
        print(f"Executing MongoDB query: {sql}")
mysql = MySQLDatabase()
mongo = MongoDatabase()

mysql.connect()
mysql.query("SELECT * FROM users")

mongo.connect()
mongo.query("db.users.find()")
# Out:
# Connecting to MySQL Database
# Executing MySQL query: SELECT * FROM users
# Connecting to MongoDB Database
# Executing MongoDB query: db.users.find()

# %%
## 15. Class Name: Shape3D
Problem
Create an abstract class named Shape3D.
Explanation
Three-dimensional shapes have different formulas.
Create abstract methods:
• volume()
• surface_area()

Sumit Sir Notes
Create subclasses:
• Cube
• Sphere

# %%
## 16. Class Name: Shape
Problem
Create an abstract class named Shape.
Explanation
The constructor should accept a shape's color.
__init__(self, color)
Create an abstract method:
• area()
Create subclass:
• Circle
Use super() to initialize the color.

# %%
from abc import ABC, abstractmethod
import math

class Shape(ABC):
    def __init__(self, color):
        self.color = color

    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, color, radius):
        super().__init__(color)
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

cir = Circle("pink", 6)

print("Color:", cir.color)
print("Area:", cir.area())
# Out:
# Color: pink
# Area: 113.09733552923255

# %%
## 17. Class Name: Vehicle
Problem
Create an abstract class named Vehicle.
Explanation
Store the vehicle brand in the constructor.
__init__(self, brand)
Create abstract methods:
• start()
• stop()
Create subclass:
• Car
Use super() to initialize the brand.

# %%
class Vehicle(ABC):
    def __init__(self,brand):
        self.brand=brand


    @abstractmethod
    def start(self):
        pass

    @abstractmethod
    def stop(self):
        pass

class Car(Vehicle):
    def __init__(self,brand):
        super().__init__(brand)

    def start(self):
        print("when you push key then car start")

    def stop(self):
        print("when you push break car stop")


car=Car("thar")
print("Brand:", car.brand)
car.start()
car.stop()
# Out:
# Brand: thar
# when you push key then car start
# when you push break car stop

# %%
## 18. Class Name: Animal
Problem
Create an abstract class named Animal.
Explanation
Store the animal's name in the constructor.
__init__(self, name)
Create abstract method:
• make_sound()
Create subclass:
• Dog
Use super() to initialize the name.

# %%
class Animal(ABC):
    def __init__(self,name):
        self.name=name

    @abstractmethod
    def make_sound(self):
        pass

class  Dog(Animal):
    def __init__(self,name):
        super().__init__(name)

    def make_sound(self):
        print("bhouuuuuuuuuu!")


animal=Dog("rocky")
print("name",)
animal.make_sound()
# Out:
# bhouuuuuuuuuu!

# %%
## 19. Class Name: Payment
Problem
Create an abstract class named Payment.
Explanation
Store the payment amount in the constructor.
__init__(self, amount)
Create abstract method:
• process_payment()
Create subclasses:
• CreditCard
• Cash
Use super() to initialize the amount.

# %%
from abc import ABC, abstractmethod
class Payment(ABC):
    def __init__(self,amount):
        self.amount=amount
    @abstractmethod
    def process_payment(self):
        pass
class CreditCard(Payment):
    def __init__(self,amount):
        super().__init__(amount)

    def process_payment(self):
        print("proccessing CreditCard payment",self.amount)

class Cash(Payment):
    def __init__(self,amount):
        super().__init__(amount)
        #self.credit_no=credit_no

    def process_payment(self):
        print("proccessing cash payment",self.amount)


payment=CreditCard(1200)
payment.process_payment()
payment=Cash(300)
payment.process_payment()
# Out:
# proccessing CreditCard payment 1200
# proccessing cash payment 300

# %%
## 20. Class Name: Employee
Problem
Create an abstract class named Employee.
Explanation
Store the employee name.
__init__(self, name)
Create abstract method:
• calculate_bonus()
Create subclass:
• Manager
Use super() to initialize the name.

# %%
class Employee(ABC):
    def __init__(self,name):
        self.name=name
    @abstractmethod
    def calculate_bonus(self):
        pass

class Manager(Employee):
    def __init__(self,name):
        super().__init__(name)

    def calculate_bonus(self):
        print("calculate bonus from manager:",self.name)


       
Employee = Manager("gokul")
#print("manager",Employee.Manager())
Employee.calculate_bonus()
# Out:
# calculate bonus from manager: gokul

# %%
## 21. Class Name: Report
Problem
Create an abstract class named Report.
Explanation
Store the report title.
__init__(self, title)
Create abstract method:
• generate()
Create subclass:
• PDFReport
Use super() to initialize the title.

# %%
class Report(ABC):
    def __init__(self,title):
        self.title=title

    @abstractmethod
    def generate(self):
        pass

class PDFReport(Report):
    def __init__(self,title):
        super().__init__(title)

    def generate(self):
        print("generate your pdf",self.title)


pdf=PDFReport("bajigar gokul")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 class Report(ABC):
#       2     def __init__(self,title):
#       3         self.title=title
#
# NameError: name 'ABC' is not defined
