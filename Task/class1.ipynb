# %% [markdown]
# ##1 creat a list named students with 5 student name and print it

# %% [markdown]
# ## creat a list named students with 5 student name and print it

# %%
students=["gokul","binod","akash","anand","alok"]
print(students)
# Out:
# ['gokul', 'binod', 'akash', 'anand', 'alok']

# %% [markdown]
# ## creat a list number=[10,20,30,40,50] and print its type and length using len()

# %%
num=[10,20,30,40,50,]
print(type(num))
print(len(num))
print(num)
# Out:
# <class 'list'>
# 5
# [10, 20, 30, 40, 50]

# %% [markdown]
# ## creat an empty list and append 3 number info it using append()

# %%
list=[]
a=[10,20,30,]
list.append(a)
print(list)
# Out:
# [[10, 20, 30]]

# %% [markdown]
# ##  4 give list=[1,2,3,],use extend() to add[4,5,6,] to it

# %%
list=[1,2,3,]
a=[4,5,6,]
list.extend(a)
print(list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ## 5 use insert() to add number 100 at index 2 in the list[10,20,30,40,]

# %%
list=[10,20,30,40,]
list.insert(2,100)
print(list)
# Out:
# [10, 20, 100, 30, 40]

# %% [markdown]
# ## 6 remove the element 50 from the list[10,20,50,30,50,50,]using remove()

# %%
list=[10,20,30,50,60,]
list.remove(50)
print(list)
# Out:
# [10, 20, 30, 60]

# %% [markdown]
# ## 7 use pop() to remove the last element form list=[5,10,15,20,]and print the list

# %%
list=[5,10,15,30,]
list.pop()
print(list)
# Out:
# [5, 10, 15]

# %% [markdown]
# ## 8 clear all element from list data=[1,2,3,4,]

# %%
list=[1,2,3,4,5,6,]
list.clear()
print(list)
# Out:
# []

# %% [markdown]
# ## 9 find the index 25 in the list[10,20,25,60,30]

# %%
list=[10,20,25,60,30,]
list=list.index(25)
print(list)
# Out:
# 2

# %% [markdown]
# ## 10 count how many time 7 appene in the list=[7,5,6,2,7,7,5,7,]

# %%
list=[7,5,6,2,7,7,5,7,]
list=list.count(7)
print(list)
# Out:
# 4

# %% [markdown]
# ## 11 sort the list[5,6,4,5,89,35]

# %%
list=[5,6,4,5,89,35]
list.sort()
print(list)
# Out:
# [4, 5, 5, 6, 35, 89]

# %% [markdown]
# ## 12 sort the list[5,6,4,5,89,35] in decending order

# %%
list=[5,6,4,5,89,35]
list.sort(reverse=True)
print(list)
# Out:
# [89, 35, 6, 5, 5, 4]

# %% [markdown]
# ## 13 reverese the list fruit=["apple","mango","orange"] using reverse()

# %%
fruit=["apple","mango","orange"]
fruit.reverse()
print(fruit)
# Out:
# ['orange', 'mango', 'apple']

# %% [markdown]
# ## 14 creat a copy of list=[1,2,3] using copy()

# %%
list=[1,2,3]
list.copy()
print(list)
# Out:
# [1, 2, 3]

# %% [markdown]
# ## 15 take the sentence from user that is ("i love python programing") and convert it into a list of wortd

# %%
word=("i love python programming")
word=word.split(" ")
print(word)
# Out:
# ['i', 'love', 'python', 'programming']

# %% [markdown]
# ## 16 creat a list of 5 number.append 3 more number  then sort it in decending order

# %%
list=[1,2,3,4,5,]
list.append(6)
list.append(7)
list.append(8)
list.sort(reverse=True)
print(list)
# Out:
# [8, 7, 6, 5, 4, 3, 2, 1]

# %% [markdown]
# ## 17 creat a list inseert "python"at index0 then remove last element using poop() and print its len()

# %%
list=[1,"gokul",2,5,2.0]
list.insert(0,"python")
list.pop()
print(list)
len(list)
# Out:
# ['python', 1, 'gokul', 2, 5]
# 5

# %% [markdown]
# ## 18 take a 5 city name as input from user and stor them in a list .then print them in revers order

# %%
l = []
for _ in range (5):
    city=input("enter your city:")
    l.append(city)
# Out:
# enter your city: hyd
# enter your city: che
# enter your city: mum
# enter your city: ban
# enter your city: goa

# %%
l
# Out:
# ['hyd', 'che', 'mum', 'ban', 'goa']

# %%
list(reversed(l))
# Out:
# ['goa', 'ban', 'mum', 'che', 'hyd']

# %%
l2 = []
for i in l:
    l2 = [i] + l2

# %%
l2
# Out:
# ['goa', 'ban', 'mum', 'che', 'hyd']

# %% [markdown]
# ## 19 given data =[10,20,30,30,50,30,40,30,] remove all occurance of 30 using loop

# %%
data=[10,20,30,30,50,30,40,30,]
data.remove(30)
data.remove(30)
data.remove(30)
data.remove(30)
print(data)
# Out:
# [10, 20, 50, 40]

# %% [markdown]
# ## 20 creat a list of student marks.sort it find the higest and lowest mark using list

# %%
mark=[33,54,68,98,56,78,]
mark.sort()
print(mark)
print(mark[0])
print(mark[-1])
# Out:
# [33, 54, 56, 68, 78, 98]
# 33
# 98

# %%
a=3
b=6
c=8
list=[a,b,c]
list.sort()
print(list[0])
print(list[-1])
# Out:
# 3
# 8
