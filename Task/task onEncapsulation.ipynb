# %% [markdown]
# ## Encapsulation Practice Questions (1–15)
# ## 1. Class Name: BankAccount
# ## Problem
# ## Create a class named BankAccount.
# ## Explanation
# ## A bank account stores money. The balance should not be directly accessible from outside
# ## the class, so create a private attribute named __balance.
# ## Implement the following methods:
# ## • deposit(amount)
# ## o Deposit money into the account.
# ## o Amount must be greater than 0.
# ## • withdraw(amount)
# ## o Withdraw money.
# ## o Withdrawal should happen only if:
# ## ▪ amount > 0
# ## ▪ amount <= available balance

# %%
class  Bank_Account:
    def __init__(self,ac_no,balance):
        self.Account_no=ac_no
        self.__Balance=balance
    
    def get_balance(self):
        return self.__Balance

    ## creat following method
    def deposit(self,amount):
        if amount>=0:
            self.__Balance+=amount
            print("money deposit successfully",self.__Balance)

        else:
            print("please entrer curret amount")

    ## creat following method
    def  withdraw(self,amount):
        if amount>=0:
            if amount<=self.__Balance:
                self.__Balance-=amount
                print("withdraw amount is",amount)
                print("remaining balance is ",self.__Balance)
            else:
                print("please enter valid amount")

        else:
            print("please valid balance")
## creat class object
b=Bank_Account(12345256,500)
b.deposit(200)
b. withdraw(300)
# Out:
# money deposit successfully 700
# withdraw amount is 300
# remaining balance is  400

# %%
## 2. Class Name: Student
Problem
Create a class named Student.
Explanation
Every student has marks that should be private.
Create:
• Private attribute __marks
Methods:
• set_marks(marks)
o Accept marks only between 0 and 100.
• get_marks()

o Return the student's marks.

# %%
class Student:
    def __init__(self,name,mark):
        self.Student_name=name
        self.__Student_mark=mark

    def get_mark(self):
        return self.__Student_mark

    def display_info(self):
        print("student name is ",self.Student_name)
        print("student mark is",self.__Student_mark)

    ## creat following method
    def Student(self,mark):
        if mark>=0 and mark<=100:
            print("mark is ",mark)

        else:
            print("please invalid mark")



s=Student("gokul",95)
s.Student(85)
s. display_info()
# Out:
# mark is  85
# student name is  gokul
# student mark is 95

# %%
## 3. Class Name: Employee
Problem
Create a class named Employee.
Explanation
Salary should not be modified directly.
Create:
• Private attribute __salary
Methods:
• set_salary(new_salary)
o Salary cannot decrease by more than 10% of the current salary.
• get_salary()
Example:
Current Salary = 50,000
Allowed minimum = 45,000
New salary = 40,000

# %%
class Employee:
    def __init__(self,emp_name,salary):
        self.Employee_name=emp_name
        self.__Employee_salary=salary

    def get_salary(self):
        return self.__Employee_salary

    def set_salary(self,new_salary):
        allowed_minimum =self.__Employee_salary*10.0
        
        if  new_salary >= allowed_minimum:
            print("salary update successfully")

        else:
            print("salary decrease more then 10% ")


    def display_info(self):
        print("employee name is",self.Employee_name)
        print("employee salary is ",self.__Employee_salary)



emp=Employee("gokul",50000)
emp.set_salary(40000)
print(emp.get_salary())
emp.set_salary(46000)
print(emp.get_salary())
emp.display_info()
# Out:
# salary decrease more then 10%
# 50000
# salary decrease more then 10%
# 50000
# employee name is gokul
# employee salary is  50000

# %%
## 4. Class Name: Mobile
Problem
Create a class named Mobile.
Explanation
Price should always be positive.
Private attribute:
• __price
Methods:
• set_price(price)
• get_price()
Validation:
Price > 0

# %%
class Mobile:
    def __init__(self,mob_name,mob_price):
        self.Mobile_name=mob_name
        self.__Mobile_price=mob_price

    def get_mobile_price(self):
        return self.__Mobile_price

    def set_price(self,price):
        if price >=0:
            self.__Mobile_price = price
            print("update successfully")

        else:
            print("Price should always be positive")

    def display_info(self):
        print("your mobil name is ",self.Mobile_name)
        print("your mobile price is ",self.__Mobile_price)
        

m= Mobile("readme",13000)
m.set_price(1200)
print(m.get_mobile_price())

m.display_info()
# Out:
# update successfully
# 1200
# your mobil name is  readme
# your mobile price is  1200

# %%
## 5. Class Name: Person
Problem
Create a class named Person.
Explanation
Store age privately.
Private attribute:
• __age
Methods:
• set_age(age)
• get_age()
Validation:
Age should be between
0 and 120

# %%
class person:
    def __init__(self,name,age):
        self.Person_name=name
        self.__Person_age=age

    def get_age(self):
        return self.__Person_age

    def set_age(self,age):
        if age>=0 :
            self.__Person_age= age
            print("age are update successfuly")

        else:
            print("please enter your age")

    def display_info(self):
        print("your name is ",self.Person_name)
        print("your age is ",self.__Person_age)



person=person("gokul",16)
person.set_age(21)
print(person. get_age())
person.display_info()
# Out:
# age are update successfuly
# 21
# your name is  gokul
# your age is  21

# %%
## 6. Class Name: Product
Problem
Create a class named Product.
Explanation
Store
• private __price
• private __stock
Methods:
• update_price(new_price)
• update_stock(quantity)
Validation:
Price cannot be negative.
Stock cannot become negative.

# %%
class Product:

    def __init__(self,name,price,stock):
        self.name=name
        self.__price=price
        self.__stock=stock
     ## 
    def get_price(self):
        return self.__price

    def get_stock(self):
        return self.__stock

    ## creat folling method
    def update_price(self,new_price):
        if new_price >=0:
            self.__price= new_price
            print("price are update",self.__price)

        else:
            print("please enter positive value")

    def  update_stock(self,quantity):
        if  quantity>=0:
            self.__stock= quantity
            print("quantity are update",self.__stock)

        else:
            print("please enter positive value")

   ## display info
    def display_info(self):
        print("your product name",self.name)
        print("your product price ",self.__price)
        print("your product stock ",self.__stock)

## class object
p=Product("laptop",50000,12)
p.update_price(40000)
p.update_stock(13)
p.display_info()
# Out:
# price are update 40000
# quantity are update 13
# your product name laptop
# your product price  40000
# your product stock  13

# %%
## 7. Class Name: Car
Problem
Create class Car.
Explanation
Store privately
• __model
• __year
Provide
• get_model()
• set_model()
• get_year()
• set_year()
Validation:
Year cannot be greater than current year.

# %%
class Car:
    def __init__(self, car_name, model, year):
        self.Car_name = car_name
        self.__model = model
        self.__year = year

    def get_model(self):
        return self.__model

    def get_year(self):
        return self.__year

    def set_model(self, model):
        self.__model = model

    def set_year(self, year):
        current_year = year

        if year <= current_year:
            self.__year = year
            print("Year updated:", self.__year)
        else:
            print("Year cannot be greater than the current year!")

    def display_info(self):
        print("Car name:", self.Car_name)
        print("Car model:", self.__model)
        print("Car year:", self.__year)

        
c=Car("toyota","furtuner",2012)
c.set_model("innova")
c.set_year(2030)
c.display_info()
# Out:
# Year updated: 2030
# Car name: toyota
# Car model: innova
# Car year: 2030

# %%
## 8. Class Name: User
Problem
Create class User.
Explanation
Password must remain private.
Private attribute
__password
Method
change_password(new_password)
Validation
Password length ≥ 8

# %%
class User:
    def __init__(self, user_name, password):
        self.User_name = user_name
        self.__Password = password

    def get_password(self):
        return self.__Password

    def change_password(self, new_password):
        if len(new_password) >= 8:
            self.__Password = new_password
            print("Password updated:", self.__Password)
        else:
            print("Please enter a valid password (minimum 8 characters).")

    def display_info(self):
        print("User name:", self.User_name)
        print("User password:", self.__Password)


user = User("gokul1234", "12345678")
user.change_password("12354678")
user.display_info()
# Out:
# Password updated: 12354678
# User name: gokul1234
# User password: 12354678

# %%
## 9. Class Name: Rectangle
Problem
Create class Rectangle.
Explanation
Private attributes
• __length
• __width
Methods
• set_length()
• get_length()
• set_width()
• get_width()
• area()
Validation
Length and width must be positive.

# %%
class Rectangle:
    def __init__(self,length,width):
        self.__Length=length
        self.__Width=width
    def get_length(self):
        return self.__Length

    def set_length(self,length):
        if length >0:
            self.__Length=length
        else:
            print("length most be positive")

    def get_width(self,width):
        if width > 0:
            self.__Width=width

        else:
            print("width most be positive")


    def area(self):
        return self.__Length * self.__Width

    def display_info(self):
        print("length of the Rectangle",self.__Length)
        print("width of the Rectangle",self.__Width)

r=Rectangle(10,5)
r.display_info()
##r.set_length(10)
##r.set_width(5)
print("area",r.area())
## r.display_info()
# Out:
# length of the Rectangle 10
# width of the Rectangle 5
# area 50

# %%
## 10. Class Name: Account
Problem
Create class Account.
Explanation
Private attribute
__balance
Whenever balance changes,
store every balance value inside a class variable
Example
history = []
Methods
• deposit()
• withdraw()
Every successful update should append the latest balance to history.

# %%
class Account:
    history = []  

    def __init__(self, balance=0):
        self.__balance = balance
        Account.history.append(self.__balance)

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            Account.history.append(self.__balance)
            return True
        return False

    def withdraw(self, amount):
        if amount > 0 and amount <= self.__balance:
            self.__balance -= amount
            Account.history.append(self.__balance)
            return True
        return False

    def get_balance(self):
        return self.__balance

acc = Account(1000)

acc.deposit(500)    
acc.withdraw(300)    
acc.withdraw(2000)    

print(acc.get_balance())
print(Account.history)
# Out:
# 1200
# [1000, 1500, 1200]

# %%
## 11. Class Name: Temperature
Problem
Create class Temperature.
Explanation
Store temperature privately.
Private attribute
__celsius
Methods
• set_celsius()
• get_celsius()
Also create
• to_fahrenheit()
Formula
F = (C × 9/5) + 32

# %%
class Temperature:
    def __init__(self, celsius=0):
        self.__celsius = celsius  

    def set_celsius(self, celsius):
        self.__celsius = celsius

    def get_celsius(self):
        return self.__celsius

    def to_fahrenheit(self):
        return (self.__celsius * 9/5) + 32

temp = Temperature()

temp.set_celsius(25)

print("Celsius:", temp.get_celsius())
print("Fahrenheit:", temp.to_fahrenheit())
# Out:
# Celsius: 25
# Fahrenheit: 77.0

# %%
## 12. Class Name: Book
Problem
Create class Book.
Explanation
Private attribute
__price
Setter rule

Sumit Sir Notes
If price > 500
automatically apply
10% discount
Store discounted price.
Getter should return final stored price.

# %%
class Book:
    def __init__(self, price=0):
        self.__price = 0  
        self.set_price(price)

    def set_price(self, price):
        if price > 500:
            self.__price = price - (price * 10 / 100) 
        else:
            self.__price = price

    def get_price(self):
        return self.__price


book = Book()

book.set_price(1000)

print("Final Price:", book.get_price())
# Out:
# Final Price: 900.0

# %%
## 13. Class Name: Player
Problem
Create class Player.
Explanation
Private attribute
__score
Methods
• set_score()
• get_score()
Validation
Score cannot be negative.

# %%
class Player:
    def __init__(self, score=0):
        self.__score = 0  
        self.set_score(score)

    def set_score(self, score):
        if score >= 0:
            self.__score = score
        else:
            print("Score cannot be negative")

    def get_score(self):
        return self.__score


player = Player()

player.set_score(50)

print("Score:", player.get_score())

player.set_score(-10)
# Out:
# Score: 50
# Score cannot be negative

# %%
## 14. Class Name: Laptop
Problem
Create class Laptop.
Explanation
Private attributes
• __ram
• __storage
Provide
• getter
• setter

Sumit Sir Notes
Validation
RAM and Storage should always be positive.

# %%
class Laptop:
    def __init__(self, ram=0, storage=0):
        self.__ram = 0       # private attribute
        self.__storage = 0   # private attribute
        self.set_ram(ram)
        self.set_storage(storage)


    def set_ram(self, ram):
        if ram > 0:
            self.__ram = ram
        else:
            print("RAM should always be positive")
    def get_ram(self):
        return self.__ram

    def set_storage(self, storage):
        if storage > 0:
            self.__storage = storage
        else:
            print("Storage should always be positive")

    def get_storage(self):
        return self.__storage

laptop = Laptop()

laptop.set_ram(16)
laptop.set_storage(512)

print("RAM:", laptop.get_ram(), "GB")
print("Storage:", laptop.get_storage(), "GB")

laptop.set_ram(-8)
laptop.set_storage(-256)
# Out:
# RAM should always be positive
# Storage should always be positive
# RAM: 16 GB
# Storage: 512 GB
# RAM should always be positive
# Storage should always be positive

# %%
## 15. Class Name: Employee
Problem
Create class Employee.
Explanation
Private attributes
• __id
• __salary
Create getter methods.
Finally,
outside the class,
try
employee.__salary
Observe the error.
Then access using
name mangling
to understand how Python stores private attributes.

# %%
class Employee:
    def __init__(self, emp_id, salary):
        self.__id = emp_id          
        self.__salary = salary     

    def get_id(self):
        return self.__id

    def get_salary(self):
        return self.__salary


employee = Employee(101, 50000)

print("Employee ID:", employee.get_id())
print("Salary:", employee.get_salary())
print(employee.__salary)
# Out:
# Employee ID: 101
# Salary: 50000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 17
#      15 print("Employee ID:", employee.get_id())
#      16 print("Salary:", employee.get_salary())
# ---> 17 print(employee.__salary)
#
# AttributeError: 'Employee' object has no attribute '__salary'

# %%
## 16. Class Name: Shape
Problem
Create an abstract class Shape.
Explanation
Declare abstract methods
• calculate_area()

Sumit Sir Notes
• calculate_perimeter()
Create subclasses like
• Circle
• Rectangle
Implement both methods.

# %%
from abc import ABC, abstractmethod
import math

class Shape(ABC):

    @abstractmethod
    def calculate_area(self):
        pass

    @abstractmethod
    def calculate_perimeter(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return math.pi * self.radius * self.radius

    def calculate_perimeter(self):
        return 2 * math.pi * self.radius

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

    def calculate_perimeter(self):
        return 2 * (self.length + self.width)


circle = Circle(5)

print("Circle Area:", circle.calculate_area())
print("Circle Perimeter:", circle.calculate_perimeter())

rectangle = Rectangle(10, 5)

print("Rectangle Area:", rectangle.calculate_area())
print("Rectangle Perimeter:", rectangle.calculate_perimeter())
# Out:
# Circle Area: 78.53981633974483
# Circle Perimeter: 31.41592653589793
# Rectangle Area: 50
# Rectangle Perimeter: 30

# %%
## 17. Class Name: Vehicle
Problem
Create abstract class Vehicle.
Explanation
Abstract methods
• start()
• stop()
Implement in
• Car
• Bike
Each subclass should define how the vehicle starts and stops.

# %%
from abc import ABC, abstractmethod
class Vehicle(ABC):

    @abstractmethod
    def start(self):
        pass

    @abstractmethod
    def stop(self):
        pass


# Car subclass
class Car(Vehicle):

    def start(self):
        print("Car starts with a key or push button")

    def stop(self):
        print("Car stops using brakes")


# Bike subclass
class Bike(Vehicle):

    def start(self):
        print("Bike starts with a kick or self-start button")

    def stop(self):
        print("Bike stops using brakes")

car = Car()
car.start()
car.stop()

bike = Bike()
bike.start()
bike.stop()
# Out:
# Car starts with a key or push button
# Car stops using brakes
# Bike starts with a kick or self-start button
# Bike stops using brakes

# %%
## 18. Class Name: Payment
Problem
Create abstract class Payment.
Explanation
Abstract method
process_payment(amount)
Create subclasses
• CreditCardPayment
• UPIPayment
Each should process payment differently.

# %%
from abc import ABC, abstractmethod
class Payment(ABC):

    @abstractmethod
    def process_payment(self, amount):
        pass

class CreditCardPayment(Payment):

    def process_payment(self, amount):
        print(f"Processing ${amount} payment using Credit Card")

class UPIPayment(Payment):

    def process_payment(self, amount):
        print(f"Processing ${amount} payment using UPI")


credit_card = CreditCardPayment()
credit_card.process_payment(500)

upi = UPIPayment()
upi.process_payment(300)
# Out:
# Processing $500 payment using Credit Card
# Processing $300 payment using UPI

# %%
## 19. Class Name: Animal
Problem
Create abstract class Animal.
Explanation
Abstract method
make_sound()
Create subclasses
• Dog
• Cat
Each returns its own sound.

# %%
from abc import ABC, abstractmethod

# Abstract class
class Animal(ABC):

    @abstractmethod
    def make_sound(self):
        pass


# Dog subclass
class Dog(Animal):

    def make_sound(self):
        return "Dog says: Woof Woof"


# Cat subclass
class Cat(Animal):

    def make_sound(self):
        return "Cat says: Meow Meow"


# Example usage
dog = Dog()
print(dog.make_sound())

cat = Cat()
print(cat.make_sound())
# Out:
# Dog says: Woof Woof
# Cat says: Meow Meow

# %%
## 20. Class Name: Report
Problem
Create abstract class Report.
Explanation
Abstract method
generate_report()
Create
• PDFReport
• ExcelReport
Each generates report differently.

# %%
from abc import ABC, abstractmethod
class Report(ABC):

    @abstractmethod
    def generate_report(self):
        pass


class PDFReport(Report):

    def generate_report(self):
        print("Generating report in PDF format")

class ExcelReport(Report):

    def generate_report(self):
        print("Generating report in Excel format")
pdf = PDFReport()
pdf.generate_report()

excel = ExcelReport()
excel.generate_report()
# Out:
# Generating report in PDF format
# Generating report in Excel format

# %%
## 21. Class Name: BankAccount
Problem
Create abstract class BankAccount.
Explanation
Abstract method

Sumit Sir Notes
calculate_interest()
Implement in
• SavingsAccount
• CurrentAccount
Each account type should use a different interest calculation.

# %%
from abc import ABC, abstractmethod

class BankAccount(ABC):

    @abstractmethod
    def calculate_interest(self, amount):
        pass

class SavingsAccount(BankAccount):

    def calculate_interest(self, amount):
        interest = amount * 0.05   
        return interest


class CurrentAccount(BankAccount):

    def calculate_interest(self, amount):
        interest = amount * 0.02   
        return interest


savings = SavingsAccount()
print("Savings Account Interest:", savings.calculate_interest(10000))

current = CurrentAccount()
print("Current Account Interest:", current.calculate_interest(10000))
# Out:
# Savings Account Interest: 500.0
# Current Account Interest: 200.0

# %%
## 22. Class Name: Device
Problem
Create abstract class Device.
Explanation
Abstract methods
• turn_on()
• turn_off()
Implement in
• TV
• Laptop
• Fan
Each device should define its own behavior.

# %%
from abc import ABC, abstractmethod
class Device(ABC):

    @abstractmethod
    def turn_on(self):
        pass

    @abstractmethod
    def turn_off(self):
        pass

class TV(Device):

    def turn_on(self):
        print("TV turns on using remote control")

    def turn_off(self):
        print("TV turns off using remote control")

class Laptop(Device):

    def turn_on(self):
        print("Laptop starts by pressing the power button")

    def turn_off(self):
        print("Laptop shuts down using the operating system")

class Fan(Device):

    def turn_on(self):
        print("Fan starts rotating when switched on")

    def turn_off(self):
        print("Fan stops rotating when switched off")

tv = TV()
tv.turn_on()
tv.turn_off()

laptop = Laptop()
laptop.turn_on()
laptop.turn_off()

fan = Fan()
fan.turn_on()
fan.turn_off()
# Out:
# TV turns on using remote control
# TV turns off using remote control
# Laptop starts by pressing the power button
# Laptop shuts down using the operating system
# Fan starts rotating when switched on
# Fan stops rotating when switched off

# %%
## 23. Class Name: Calculator
Problem
Create abstract class Calculator.
Explanation
Abstract method
compute(a, b)
Implement in
• AddCalculator
• MultiplyCalculator

Sumit Sir Notes
Each subclass performs a different operation.

# %%
from abc import ABC, abstractmethod

class Calculator(ABC):

    @abstractmethod
    def compute(self, a, b):
        pass

class AddCalculator(Calculator):

    def compute(self, a, b):
        return a + b

class MultiplyCalculator(Calculator):

    def compute(self, a, b):
        return a * b
add = AddCalculator()
print("Addition:", add.compute(10, 5))

multiply = MultiplyCalculator()
print("Multiplication:", multiply.compute(10, 5))
# Out:
# Addition: 15
# Multiplication: 50

# %%
## 24. Class Name: Employee
Problem
Create abstract class Employee.
Explanation
Abstract method
calculate_bonus()
Create subclasses
• Manager
• Developer
• HR
Each has its own bonus calculation rule.

# %%
from abc import ABC, abstractmethod
class Employee(ABC):

    @abstractmethod
    def calculate_bonus(self, salary):
        pass

class Manager(Employee):

    def calculate_bonus(self, salary):
        return salary * 0.20 

class Developer(Employee):

    def calculate_bonus(self, salary):
        return salary * 0.10  

class HR(Employee):

    def calculate_bonus(self, salary):
        return salary * 0.05   # 5% bonus


manager = Manager()
print("Manager Bonus:", manager.calculate_bonus(50000))

developer = Developer()
print("Developer Bonus:", developer.calculate_bonus(50000))

hr = HR()
print("HR Bonus:", hr.calculate_bonus(50000))
# Out:
# Manager Bonus: 10000.0
# Developer Bonus: 5000.0
# HR Bonus: 2500.0

# %%
## 25. Class Name: Shape3D
Problem
Create abstract class Shape3D.
Explanation
Abstract methods
• volume()
• surface_area()
Implement in
• Cube
• Sphere
• Cylinder
Each uses different formulas.

# %%
from abc import ABC, abstractmethod
import math

class Shape3D(ABC):

    @abstractmethod
    def volume(self):
        pass

    @abstractmethod
    def surface_area(self):
        pass

class Cube(Shape3D):

    def __init__(self, side):
        self.side = side

    def volume(self):
        return self.side ** 3

    def surface_area(self):
        return 6 * (self.side ** 2)

class Sphere(Shape3D):

    def __init__(self, radius):
        self.radius = radius

    def volume(self):
        return (4/3) * math.pi * (self.radius ** 3)

    def surface_area(self):
        return 4 * math.pi * (self.radius ** 2)

class Cylinder(Shape3D):

    def __init__(self, radius, height):
        self.radius = radius
        self.height = height

    def volume(self):
        return math.pi * (self.radius ** 2) * self.height

    def surface_area(self):
        return 2 * math.pi * self.radius * (self.radius + self.height)


cube = Cube(5)
print("Cube Volume:", cube.volume())
print("Cube Surface Area:", cube.surface_area())

sphere = Sphere(3)
print("Sphere Volume:", sphere.volume())
print("Sphere Surface Area:", sphere.surface_area())

cylinder = Cylinder(2, 6)
print("Cylinder Volume:", cylinder.volume())
print("Cylinder Surface Area:", cylinder.surface_area())
# Out:
# Cube Volume: 125
# Cube Surface Area: 150
# Sphere Volume: 113.09733552923254
# Sphere Surface Area: 113.09733552923255
# Cylinder Volume: 75.39822368615503
# Cylinder Surface Area: 100.53096491487338

# %%
##
