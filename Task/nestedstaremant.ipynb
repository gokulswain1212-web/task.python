# %% [markdown]
# ## 1. Take a number as input. If the number is positive, check whether it is even or odd
# and print the result.

# %%
num=int(input("enter your number:"))

if num>=0:
    print("numberr is +ve")
    if num%2==0:
        print("number is even")
    else:
        print("number is add")
else:
    print("number is -ve")
# Out:
# enter your number: 5
# numberr is +ve
# number is add

# %% [markdown]
# ## 2. Take age as input. If age is greater than or equal to 18, check if the person is a
# senior citizen (age >= 60) or adult.

# %%
num=int(input("enter your number:"))

if num>=18:
    print("the parsion is adult")
    if num>=60:
        print("the parsion is senior citizen ")
    else :
        print("not senior citizen ")
else:
    print("the  parsion is not adult")
# Out:
# enter your number: 89
# the parsion is adult
# the parsion is senior citizen

# %% [markdown]
# ## 3. Take a single character. If it is an alphabet, check whether it is uppercase or
# lowercase.

# %%
char=input("enter your character:")

if char>='a'and char<='z':
    print("the character is alphabet")

    if char>='A'and char<='Z':
        print("the character is uppercase")
    else:
        print("the character is lowercase")
else:
    print("not alphabet")
# Out:
# enter your character: a
# the character is alphabet
# the character is lowercase

# %% [markdown]
# ## 4. Take three numbers as input and print the largest number using

# %%
num1=int(input("enter your number:"))
num2=int(input("enter your number:"))
num3=int(input("enter your number:"))

if num1>num2:
    print("the largest number is:",num1)
    if num2>=num1:
        print("the largeest number is:",num2)
    else:
        print("the largest number is:",num3)
else:
    print("the largest number is:",num3)
# Out:
# enter your number: 5
# enter your number: 6
# enter your number: 9
# the largest number is: 9

# %% [markdown]
# ## 5. Take student marks. If marks >= 40 (Pass), then further check if marks >= 75 to
# print "Pass with Distinction".

# %%
mark=60

if mark>=40:
    print("the student is pass")
    if mark>=75:
        print("pass with distinction")
    else:
        print("pass but good")
else:
    print("fail")
# Out:
# the student is pass
# pass but good

# %% [markdown]
# ## 6. Take a number. If it is divisible by 2, check if it is also divisible by 4.

# %%
num=int(input("enter your number:"))

if num%2==0:
    print("number is divisible by 2")
    if num%4==0:
        print("number is divisible by 4 ")
    else:
        print("number is not divisiable by 4")
else:
    print("number is not divisiable by 2")
# Out:
# enter your number: 50
# number is divisible by 2
# number is not divisiable by 4

# %% [markdown]
# ## 7. Take username and password. If username is "admin", then check if the
# password is correct.

# %%
user_name=input("enter your name:")

username="gokul"
password=1234

if user_name==username:
    user_password=int(input("enter your password:"))
    print("admin")
    if user_password==password:
        print("correct password")
    else:
        print("incorrect password")
else:
    print("please enterr your name")
# Out:
# enter your name: gokul
# enter your password: 1234
# admin
# correct password

# %% [markdown]
# ## 9. Take salary and years of experience. If salary > 50000, check experience to
# decide "Manager" or "Senior Manager".

# %%
salary=50000
experience=3
user_salary=int(input("enter your salary:"))
user_experience=int(input("enter your experience:"))

if salary>=50000:
    print("manager")
    
    if experience>=user_experience:
        print("senior manager ")
    else:
        print("maneger")
else:
    print("not maneger")
# Out:
# enter your salary: 40000
# enter your experience: 2
# manager
# senior manager

# %% [markdown]
# ## 12.Take temperature. If temperature > 30 print "Hot", if between 20-30 print "Warm",
# else "Cold" using nested if.

# %%
tem=int(input("enter your tempearture:"))

if tem>=30:
    print("the tempearture is hot")
    if tem>=20 and tem<30:
        print("warm")
    else:
        print("normal warm")
else:
    print("cold")
# Out:
# enter your tempearture: 25
# cold

# %% [markdown]
# ## 13.Take three numbers. Check if all three are equal, or any two are equal using
# nested if.

# %%
num1=int(input("enter your number:"))
num2=int(input("enter your number:"))
num3=int(input("enter your number:"))

if num1==num2:
    print(f"those two num{num1} and {num2} are equal")
    if num2==num3:
        print(f"those num{num2} and {num3} are equal")
    else:
        print("number are not equal")
else:
    print("not equal")
# Out:
# enter your number: 5
# enter your number: 5
# enter your number: 5
# those two num5 and 5 are equal
# those num5 and 5 are equal

# %% [markdown]
# ## 14.Take a number. If it is positive and even, print "Positive Even Number".

# %%
num=int(input("enter your number:"))

if num%2==0:
    print("number is even")
    if num%2==0 and num>=0:
        print("number is +ve even number")
    else:
        print("number is +ve but even")
else:
    print("add numbber")
# Out:
# enter your number: 8
# number is even
# number is +ve even number

# %% [markdown]
# ## 15.Take marks of 5 subjects. If average >= 60, then check if all subjects are above
# 40 marks.

# %%
mark1=int(input("enter your mark:"))
mark2=int(input("enter your mark:"))
mark3=int(input("enter your mark:"))
mark4=int(input("enter your mark:"))
mark4=int(input("enter your mark:"))

total=mark1+mark2+mark3+mark4+mark5
average=total/500*100
if average>=60:

# %% [markdown]
# ## 16.Take username, password, and age. If username and password are correct and
# age >= 18, print "Login Successful". Else if age < 18, print age restriction
# message.

# %%
username=input("enter your name:")
age=int(input("enter your age"))

user_name="gokul"
user_password=1234
user_age=18

if username==user_name:
    password=int(input("enter your password:"))
    print("correct user name")
    if password==user_password and age>=18:
        print("correct password")
        print("login successful")
    else:
        print("age restriction message")
else:
    print("enter correct name")
# Out:
# enter your name: gokul
# enter your age 18
# enter your password: 1234
# correct user name
# correct password
# login successful

# %% [markdown]
# ##  17.Take a number. Check if it is divisible by both 3 and 5 using nested if.

# %%
num=int(input("enter your number"))

if num%3==0:
    print("number is divisible by 3")
    if  num%5==0:
        print("number is divisible by 5")
    else:
        print("number is not dib=visible by 5")
else:
    print("number is not divisible by 3")
# Out:
# enter your number 15
# number is divisible by 3
# number is divisible by 5

# %% [markdown]
# ##
